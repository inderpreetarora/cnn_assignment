# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from keras.optimizers import Adam
from tensorflow.keras.layers import Dense, Conv2D, BatchNormalization, Activation, MaxPool2D, Flatten, Dropout

# %%
## If you are using the data by mounting the google drive, use the following :
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Path for train and test images
data_dir_train = pathlib.Path('/content/gdrive/My Drive/cnn/dataset/Train/')
data_dir_test = pathlib.Path('/content/gdrive/My Drive/cnn/dataset/Test/')

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  validation_split=0.2, # 20%
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  validation_split=0.2, # 20%
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list.
# You can find the class names in the class_names attribute on these datasets.
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 8))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
init = 'normal'
lr = 1e-5
activ = 'relu'
input_sh=(180, 180, 3)

preprocessing_layers = [
    tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=input_sh)
]


model = Sequential()
model.add(tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=input_sh))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_sh))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_sh))
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
model.build()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 178, 178, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 176, 176, 32)      9248
#
#  max_pooling2d (MaxPooling2  (None, 88, 88, 32)        0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 86, 86, 64)        18496
#
#  batch_normalization (Batch  (None, 86, 86, 64)        256
#  Normalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 43, 43, 64)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 41, 41, 128)       73856
#
#  batch_normalization_1 (Bat  (None, 41, 41, 128)       512
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 20, 20, 128)       0
#  g2D)
#
#  flatten (Flatten)           (None, 51200)             0
#
#  dense (Dense)               (None, 512)               26214912
#
#  activation (Activation)     (None, 512)               0
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
#  activation_1 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 26318689 (100.40 MB)
# Trainable params: 26318305 (100.40 MB)
# Non-trainable params: 384 (1.50 KB)
# _________________________________________________________________

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 178, 178, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 176, 176, 32)      9248
#
#  max_pooling2d (MaxPooling2  (None, 88, 88, 32)        0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 86, 86, 64)        18496
#
#  batch_normalization (Batch  (None, 86, 86, 64)        256
#  Normalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 43, 43, 64)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 41, 41, 128)       73856
#
#  batch_normalization_1 (Bat  (None, 41, 41, 128)       512
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 20, 20, 128)       0
#  g2D)
#
#  flatten (Flatten)           (None, 51200)             0
#
#  dense (Dense)               (None, 512)               26214912
#
#  activation (Activation)     (None, 512)               0
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
#  activation_1 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 26318689 (100.40 MB)
# Trainable params: 26318305 (100.40 MB)
# Non-trainable params: 384 (1.50 KB)
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 10/56 [====>.........................] - ETA: 4:13 - loss: -2450.9517 - accuracy: 0.1625

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# ### Write your findings here

# %%
## We observe overfitting

# %%
loss_tr, accuracy_tr = model.evaluate(train_ds, verbose=1,)
loss_va, accuracy_va = model.evaluate(val_ds, verbose=1)

print("Training Accuracy: ", accuracy_tr)
print("Validation Accuracy: ",accuracy_va)
print("Training Loss: ",loss_tr)
print("Validation Loss", loss_va)
# Out:
# 56/56 [==============================] - 1s 18ms/step - loss: -1082665856.0000 - accuracy: 0.1724
# 14/14 [==============================] - 0s 16ms/step - loss: -1111391616.0000 - accuracy: 0.1499
# Training Accuracy:  0.1724330335855484
# Validation Accuracy:  0.14988814294338226
# Training Loss:  -1082665856.0
# Validation Loss -1111391616.0

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
# Your code goes here

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

data_1 = ImageDataGenerator(
        featurewise_center=False,  # input mean set to 0
        samplewise_center=False,  # sample mean set to 0
        featurewise_std_normalization=False,
        samplewise_std_normalization=False,
        zca_whitening=False,
        rotation_range=10,  # random images rotation
        zoom_range = 0.1, # random zoom
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip=False,
        vertical_flip=False)

image_cl_1 = ['nevus','melanoma','basal_cell_caricoma','actinic_keratosis','vasc_lesion','dermatofibroma', 'pigmented_keratosis', 'seborrheic_keratosis', 'squamous_carci']

tr_ba_1 = data_1.flow_from_directory(data_dir_train,
    target_size = (180,180),
    classes = image_cl_1,
    batch_size = 64
 )

va_ba_1 = data_1.flow_from_directory(data_dir_test,
    target_size = (180,180),
    classes = image_cl_1,
    batch_size = 64
)
# Out:
# Found 890 images belonging to 9 classes.
# Found 48 images belonging to 9 classes.

# %%
plt.figure(figsize=(8, 8))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Todo:
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

## Your code goes here

# %%
model = Sequential()
# Increasing layers
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same', input_shape=(180,180,3)))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=(2, 2)))
# Adding Dropout
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding = 'same'))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding = 'same'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(9, activation='softmax'))

# %%
model.build()
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_37 (Conv2D)          (None, 180, 180, 32)      896
#
#  conv2d_38 (Conv2D)          (None, 180, 180, 32)      9248
#
#  max_pooling2d_24 (MaxPooli  (None, 90, 90, 32)        0
#  ng2D)
#
#  dropout_23 (Dropout)        (None, 90, 90, 32)        0
#
#  conv2d_39 (Conv2D)          (None, 90, 90, 64)        18496
#
#  conv2d_40 (Conv2D)          (None, 90, 90, 64)        36928
#
#  max_pooling2d_25 (MaxPooli  (None, 45, 45, 64)        0
#  ng2D)
#
#  dropout_24 (Dropout)        (None, 45, 45, 64)        0
#
#  conv2d_41 (Conv2D)          (None, 43, 43, 128)       73856
#
#  max_pooling2d_26 (MaxPooli  (None, 21, 21, 128)       0
#  ng2D)
#
#  dropout_25 (Dropout)        (None, 21, 21, 128)       0
#
#  flatten_8 (Flatten)         (None, 56448)             0
#
#  dense_16 (Dense)            (None, 512)               28901888
#
#  dropout_26 (Dropout)        (None, 512)               0
#
#  dense_17 (Dense)            (None, 9)                 4617
#
# =================================================================
# Total params: 29045929 (110.80 MB)
# Trainable params: 29045929 (110.80 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Compiling the model

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_37 (Conv2D)          (None, 180, 180, 32)      896
#
#  conv2d_38 (Conv2D)          (None, 180, 180, 32)      9248
#
#  max_pooling2d_24 (MaxPooli  (None, 90, 90, 32)        0
#  ng2D)
#
#  dropout_23 (Dropout)        (None, 90, 90, 32)        0
#
#  conv2d_39 (Conv2D)          (None, 90, 90, 64)        18496
#
#  conv2d_40 (Conv2D)          (None, 90, 90, 64)        36928
#
#  max_pooling2d_25 (MaxPooli  (None, 45, 45, 64)        0
#  ng2D)
#
#  dropout_24 (Dropout)        (None, 45, 45, 64)        0
#
#  conv2d_41 (Conv2D)          (None, 43, 43, 128)       73856
#
#  max_pooling2d_26 (MaxPooli  (None, 21, 21, 128)       0
#  ng2D)
#
#  dropout_25 (Dropout)        (None, 21, 21, 128)       0
#
#  flatten_8 (Flatten)         (None, 56448)             0
#
#  dense_16 (Dense)            (None, 512)               28901888
#
#  dropout_26 (Dropout)        (None, 512)               0
#
#  dense_17 (Dense)            (None, 9)                 4617
#
# =================================================================
# Total params: 29045929 (110.80 MB)
# Trainable params: 29045929 (110.80 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
## history = ## your training code

# %%
epochs = 20
history = model.fit(tr_ba_1,
  epochs = epochs, validation_data=va_ba_1)
# Out:
# Epoch 1/20
# 14/14 [==============================] - 59s 4s/step - loss: 32.1785 - accuracy: 0.3652 - val_loss: 0.4174 - val_accuracy: 0.3333
# Epoch 2/20
# 14/14 [==============================] - 25s 2s/step - loss: 0.2759 - accuracy: 0.4843 - val_loss: 0.6747 - val_accuracy: 0.3542
# Epoch 3/20
# 14/14 [==============================] - 27s 2s/step - loss: 0.2316 - accuracy: 0.4584 - val_loss: 0.6749 - val_accuracy: 0.3542
# Epoch 4/20
# 14/14 [==============================] - 25s 2s/step - loss: 0.2206 - accuracy: 0.4820 - val_loss: 0.6674 - val_accuracy: 0.3542
# Epoch 5/20
# 14/14 [==============================] - 23s 2s/step - loss: 0.2108 - accuracy: 0.4966 - val_loss: 0.6653 - val_accuracy: 0.3542
# Epoch 6/20
# 14/14 [==============================] - 23s 2s/step - loss: 0.2064 - accuracy: 0.5180 - val_loss: 0.6586 - val_accuracy: 0.3542
# Epoch 7/20
# 14/14 [==============================] - 23s 2s/step - loss: 0.1998 - accuracy: 0.5315 - val_loss: 0.6532 - val_accuracy: 0.3958
# Epoch 8/20
# 14/14 [==============================] - 23s 2s/step - loss: 0.1804 - accuracy: 0.6112 - val_loss: 0.5608 - val_accuracy: 0.4583
# Epoch 9/20
# 14/14 [==============================] - 22s 2s/step - loss: 0.1914 - accuracy: 0.5989 - val_loss: 0.5504 - val_accuracy: 0.4792
# Epoch 10/20
# 14/14 [==============================] - 23s 2s/step - loss: 0.1840 - accuracy: 0.5989 - val_loss: 0.5917 - val_accuracy: 0.3958
# Epoch 11/20
# 14/14 [==============================] - 23s 2s/step - loss: 0.1791 - accuracy: 0.6011 - val_loss: 0.6217 - val_accuracy: 0.3542
# Epoch 12/20
# 14/14 [==============================] - 23s 2s/step - loss: 0.1753 - accuracy: 0.6303 - val_loss: 0.6117 - val_accuracy: 0.4167
# Epoch 13/20
# 14/14 [==============================] - 22s 2s/step - loss: 0.1620 - accuracy: 0.6629 - val_loss: 0.5840 - val_accuracy: 0.3125
# Epoch 14/20
# 14/14 [==============================] - 24s 2s/step - loss: 0.1597 - accuracy: 0.6382 - val_loss: 0.3603 - val_accuracy: 0.4375
# Epoch 15/20
# 14/14 [==============================] - 23s 2s/step - loss: 0.1543 - accuracy: 0.6584 - val_loss: 0.4152 - val_accuracy: 0.4792
# Epoch 16/20
# 14/14 [==============================] - 23s 2s/step - loss: 0.1906 - accuracy: 0.5910 - val_loss: 0.3675 - val_accuracy: 0.3750
# Epoch 17/20
# 14/14 [==============================] - 23s 2s/step - loss: 0.1602 - accuracy: 0.6506 - val_loss: 0.3805 - val_accuracy: 0.3333
# Epoch 18/20
# 14/14 [==============================] - 23s 2s/step - loss: 0.1550 - accuracy: 0.6596 - val_loss: 0.5139 - val_accuracy: 0.4167
# Epoch 19/20
# 14/14 [==============================] - 22s 2s/step - loss: 0.1586 - accuracy: 0.6539 - val_loss: 0.3822 - val_accuracy: 0.3542
# Epoch 20/20
# 14/14 [==============================] - 23s 2s/step - loss: 0.1431 - accuracy: 0.6775 - val_loss: 0.2761 - val_accuracy: 0.3958

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
## Your code goes here.
da_1 = dict()
cl_na_1 = train_ds.class_names

for i in cl_na_1:
  da_1[i] = []

plt.figure(figsize=(10, 10))
for images, labels in train_ds:
  for i in range(9):
    da_1[class_names[labels[i]]].append(images[i].numpy().astype("uint8"))

for i in da_1:
  da_1[i] = len(da_1[i])

f = plt.figure()
f.set_figwidth(20)
f.set_figheight(20)

plt.bar(range(len(da_1)), list(da_1.values()), align='center')
plt.xticks(range(len(da_1)), list(da_1.keys()))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8ae3d707e96d> in <cell line: 3>()
#       1 ## Your code goes here.
#       2 da_1 = dict()
# ----> 3 cl_na_1 = train_ds.class_names
#       4
#       5 for i in cl_na_1:
#
# NameError: name 'train_ds' is not defined

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - Which class has the least number of samples?
# #### - Which classes dominate the data in terms proportionate number of samples?

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset="To do"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
path_list = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
path_list

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new

# %%
dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = original_df.append(df2)

# %%
new_df['Label'].value_counts()

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
data_dir_train="path to directory with training data + data created using augmentor"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = ## Todo choose the correct parameter value, so that only training data is refered to,,
  image_size=(img_height, img_width),
  batch_size=batch_size)

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = ## Todo choose the correct parameter value, so that only validation data is refered to,
  image_size=(img_height, img_width),
  batch_size=batch_size)

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
## your code goes here

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
## your code goes here

# %% [markdown]
# #### **Todo:**  Train your model

# %%
epochs = 30
## Your code goes here, use 50 epochs.
history = # your model fit code

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?
